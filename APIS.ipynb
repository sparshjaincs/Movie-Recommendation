# %%
import requests
key="********"  #omdbapi key
query=input("enter movie name")
url=f"http://www.omdbapi.com/?apikey={key}&s={query}"
data=requests.get(url)
# Out:
# enter movie namejungle book

# %%
data
# Out:
# <Response [200]>

# %%
data=data.json()

# %%
data
# Out:
# {'Search': [{'Title': 'The Jungle Book',
#    'Year': '2016',
#    'imdbID': 'tt3040964',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc3NTUzNTI4MV5BMl5BanBnXkFtZTgwNjU0NjU5NzE@._V1_SX300.jpg'},
#   {'Title': 'The Jungle Book',
#    'Year': '1967',
#    'imdbID': 'tt0061852',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAwMTExODExNl5BMl5BanBnXkFtZTgwMjM2MDgyMTE@._V1_SX300.jpg'},
#   {'Title': 'The Jungle Book',
#    'Year': '1994',
#    'imdbID': 'tt0110213',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BOWRhNDBlOWQtNjNjYS00MTRiLTlhMWUtZmY1YmYwMzU4NDQxXkEyXkFqcGdeQXVyNTM5NzI0NDY@._V1_SX300.jpg'},
#   {'Title': 'The Jungle Book 2',
#    'Year': '2003',
#    'imdbID': 'tt0283426',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BNDk2NTk1NzQxN15BMl5BanBnXkFtZTYwMDMyMTg5._V1_SX300.jpg'},
#   {'Title': 'The Jungle Book',
#    'Year': '1942',
# ...

# %%
data['Search'][0]
# Out:
# {'Title': 'The Jungle Book',
#  'Year': '2016',
#  'imdbID': 'tt3040964',
#  'Type': 'movie',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc3NTUzNTI4MV5BMl5BanBnXkFtZTgwNjU0NjU5NzE@._V1_SX300.jpg'}

# %%
post=data['Search'][0]['Poster']

# %%
post
# Out:
# 'https://m.media-amazon.com/images/M/MV5BMTc3NTUzNTI4MV5BMl5BanBnXkFtZTgwNjU0NjU5NzE@._V1_SX300.jpg'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def openimg(fname):
    img =plt.imread(fname)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.show()
def download(url,fname):
    try:
        page=requests.get(url,timeout=10)
       
        if page.status_code==200:
            if page.headers['Content-Type']=='image/jpeg':
                f=open(fname,"wb")
                f.write(page.content)
                f.close()
                print(f"Successfully Downloaded {fname}")
                openimg(fname)
                
            else:
                print("Content Type:",page.headers['Content-Type'])
        else:
            print("there is error:",status_code)
    except Exception as exp:
        print("Error!!!",exp)
post=f"https://image.tmdb.org/t/p/w500/{data['poster_path']}.jpg"
download(post,post.split("/")[-1])
# Out:
# Error!!! name 'status_code' is not defined

# %%
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# {'adult': False,
#  'backdrop_path': '/mMZRKb3NVo5ZeSPEIaNW9buLWQ0.jpg',
#  'belongs_to_collection': None,
#  'budget': 63000000,
#  'genres': [{'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.foxmovies.com/movies/fight-club',
#  'id': 550,
#  'imdb_id': 'tt0137523',
#  'original_language': 'en',
#  'original_title': 'Fight Club',
#  'overview': 'A ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground "fight clubs" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.',
#  'popularity': 20.546,
#  'poster_path': '/adw6Lq9FiC9zjYEpOqfq03ituwp.jpg',
#  'production_companies': [{'id': 508,
#    'logo_path': '/7PzJdsLGlR7oW4J0J5Xcd0pHGRg.png',
#    'name': 'Regency Enterprises',
#    'origin_country': 'US'},
#   {'id': 711,
#    'logo_path': '/tEiIH5QesdheJmDAqQwvtN60727.png',
#    'name': 'Fox 2000 Pictures',
# ...

# %%
data=data.json()
print(data)
# Out:
# {'adult': False, 'backdrop_path': '/mMZRKb3NVo5ZeSPEIaNW9buLWQ0.jpg', 'belongs_to_collection': None, 'budget': 63000000, 'genres': [{'id': 18, 'name': 'Drama'}], 'homepage': 'http://www.foxmovies.com/movies/fight-club', 'id': 550, 'imdb_id': 'tt0137523', 'original_language': 'en', 'original_title': 'Fight Club', 'overview': 'A ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground "fight clubs" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.', 'popularity': 20.546, 'poster_path': '/adw6Lq9FiC9zjYEpOqfq03ituwp.jpg', 'production_companies': [{'id': 508, 'logo_path': '/7PzJdsLGlR7oW4J0J5Xcd0pHGRg.png', 'name': 'Regency Enterprises', 'origin_country': 'US'}, {'id': 711, 'logo_path': '/tEiIH5QesdheJmDAqQwvtN60727.png', 'name': 'Fox 2000 Pictures', 'origin_country': 'US'}, {'id': 20555, 'logo_path': '/hD8yEGUBlHOcfH
# ...

# %%
data['adult']
# Out:
# False

# %%
url1=f"https://api.themoviedb.org/3/movie/images?api_key={key}&language=en-U&query={query}"
data1=requests.get(url1)

# %%
data1
# Out:
# <Response [404]>

# %%
data1.json()
# Out:
# {'status_code': 34,
#  'status_message': 'The resource you requested could not be found.'}

# %%
## TMDB
query=input("enter movie:  ")
url=f"https://api.themoviedb.org/3/movie/550?api_key=**************&query={query}"  #the movie db api key
data=requests.get(url)
data
# Out:
# enter movie:  titanic
# <Response [200]>

# %%
data=data.json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-6d46641eaedf> in <module>
# ----> 1 data=data.json()
#
# AttributeError: 'dict' object has no attribute 'json'

# %%
data
# Out:
# {'adult': False,
#  'backdrop_path': '/mMZRKb3NVo5ZeSPEIaNW9buLWQ0.jpg',
#  'belongs_to_collection': None,
#  'budget': 63000000,
#  'genres': [{'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.foxmovies.com/movies/fight-club',
#  'id': 550,
#  'imdb_id': 'tt0137523',
#  'original_language': 'en',
#  'original_title': 'Fight Club',
#  'overview': 'A ticking-time-bomb insomniac and a slippery soap salesman channel primal male aggression into a shocking new form of therapy. Their concept catches on, with underground "fight clubs" forming in every town, until an eccentric gets in the way and ignites an out-of-control spiral toward oblivion.',
#  'popularity': 20.546,
#  'poster_path': '/adw6Lq9FiC9zjYEpOqfq03ituwp.jpg',
#  'production_companies': [{'id': 508,
#    'logo_path': '/7PzJdsLGlR7oW4J0J5Xcd0pHGRg.png',
#    'name': 'Regency Enterprises',
#    'origin_country': 'US'},
#   {'id': 711,
#    'logo_path': '/tEiIH5QesdheJmDAqQwvtN60727.png',
#    'name': 'Fox 2000 Pictures',
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def openimg(fname):
    img =plt.imread(fname)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.show()
def download(url,fname):
    try:
        page=requests.get(url,timeout=10)
       
        if page.status_code==200:
            if page.headers['Content-Type']=='image/jpeg':
                f=open(fname,"wb")
                f.write(page.content)
                f.close()
                print(f"Successfully Downloaded {fname}")
                openimg(fname)
                
            else:
                print("Content Type:",page.headers['Content-Type'])
        else:
            print("there is error:",status_code)
    except Exception as exp:
        print("Error!!!",exp)
post=f"https://image.tmdb.org/t/p/w500/{data['poster_path']}"
download(post,post.split("/")[-1])
# Out:
# Successfully Downloaded adw6Lq9FiC9zjYEpOqfq03ituwp.jpg

# %%
# rapid api
key="4ae47af3ccmsh91b5c261a9b9b26p1a9772jsne57decfbd06c"
response = requests.get("https://movie-database-imdb-alternative.p.rapidapi.com/?page=1&r=json&s=jungle book",
  headers={
    "X-RapidAPI-Host": "movie-database-imdb-alternative.p.rapidapi.com",
    "X-RapidAPI-Key": "*********************" ## rapidapi key
  }
)

# %%
response
# Out:
# <Response [503]>

# %%
response1 = requests.get("https://imdb8.p.rapidapi.com/title/get-ratings?tconst=tt4154749&page=1&r=json&s=Avengers+Endgame",
  headers={
    "X-RapidAPI-Host": "imdb8.p.rapidapi.com",
    "X-RapidAPI-Key": "*************************"  # the rapid api key
  }
)

# %%
response1.json()

# %%
url="https://movie-database-imdb-alternative.p.rapidapi.com/?page=1&r=json&s=Avengers+Endgame"
headers={
    "X-RapidAPI-Host": "movie-database-imdb-alternative.p.rapidapi.com",
    "X-RapidAPI-Key": "***********************************"  #rapid api key
  }
data=requests.get(url,headers)

# %%
data.json()
# Out:
# {'message': 'Missing RapidAPI application key. Go to https://docs.rapidapi.com/docs/keys to learn how to get your API application key.'}

# %%
data=requests.get("https://uflixit.p.rapidapi.com/tv-shows/popular",headers={
    "x-rapidapi-host": "uflixit.p.rapidapi.com",
    "x-rapidapi-key": "**********************************" #uflixit api key
})

# %%
data.json()['result']
# Out:
# ['tt5491994',
#  'tt7366338',
#  'tt0185906',
#  'tt0795176',
#  'tt0903747',
#  'tt0944947',
#  'tt0306414',
#  'tt6769208',
#  'tt9253866',
#  'tt2395695',
#  'tt0081846',
#  'tt2861424',
#  'tt9566030',
#  'tt0141842',
#  'tt0071075',
#  'tt0417299',
#  'tt1533395',
#  'tt0111893',
#  'tt1475582',
#  'tt1877514',
#  'tt0052520',
#  'tt1355642',
#  'tt1806234',
#  'tt0092337',
#  'tt0303461',
#  'tt0098769',
#  'tt2356777',
#  'tt7137906',
#  'tt0103359',
#  'tt0296310',
#  'tt2802850',
#  'tt0877057',
#  'tt1190634',
#  'tt3530232',
#  'tt2092588',
#  'tt0213338',
#  'tt1508238',
#  'tt2571774',
#  'tt2085059',
#  'tt0081912',
#  'tt0063929',
#  'tt0108778',
#  'tt0081834',
#  'tt0112130',
#  'tt4508902',
#  'tt0098904',
#  'tt4574334',
#  'tt4742876',
#  'tt1865718',
#  'tt0098936',
#  'tt0386676',
#  'tt3718778',
#  'tt7920978',
#  'tt0367279',
#  'tt2707408',
#  'tt0193676',
#  'tt2442560',
#  'tt0072500',
#  'tt1856010',
#  'tt0096548',
#  'tt0074006',
#  'tt0475784',
# ...

# %%
movie_name=input()
data = requests.get(f"https://uflixit.p.rapidapi.com/movies/search?query={movie_name}",headers={
    "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
    "X-RapidAPI-Key": "*******************************************"
        })
# Out:
# avengers endgame

# %%
data=data.json()

# %%
data
# Out:
# {'error': False,
#  'result': {'imdb_id': 'tt4154796', 'title': 'Avengers: Endgame'}}

# %%
response = requests.get(f"https://uflixit.p.rapidapi.com/movie/details/{data['result']['imdb_id']}",
  headers={
    "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
    "X-RapidAPI-Key": "**************************************8"
  }
)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'error': False,
#  'result': {'title': 'Avengers: Endgame',
#   'rating': '8.7',
#   'duration': 181,
#   'content': 'PG-13',
#   'published': '2019-04-24',
#   'image': 'https://m.media-amazon.com/images/M/MV5BMTc5MDE2ODcwNV5BMl5BanBnXkFtZTgwMzI2NzQ2NzM@._V1_.jpg',
#   'fanart': 'http://image.tmdb.org/t/p/original/7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg',
#   'stars': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth',
#    'Scarlett Johansson',
#    'Jeremy Renner',
#    'Don Cheadle',
#    'Paul Rudd',
#    'Benedict Cumberbatch',
#    'Chadwick Boseman',
#    'Brie Larson',
#    'Tom Holland',
#    'Karen Gillan',
#    'Zoe Saldana',
#    'Evangeline Lilly',
#    'Tessa Thompson',
#    'Rene Russo',
#    'Elizabeth Olsen',
#    'Anthony Mackie',
#    'Sebastian Stan',
#    'Tom Hiddleston',
#    'Danai Gurira',
#    'Benedict Wong',
#    'Pom Klementieff',
#    'Dave Bautista',
#    'Letitia Wright',
#    'John Slattery',
#    'Tilda Swinton',
# ...

# %%
response = requests.get("https://uflixit.p.rapidapi.com/tv-shows/popular",
  headers={
    "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
    "X-RapidAPI-Key": "************************888"   #uflixit api key
  }
)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'error': False,
#  'result': ['tt5491994',
#   'tt7366338',
#   'tt0185906',
#   'tt0795176',
#   'tt0903747',
#   'tt0944947',
#   'tt0306414',
#   'tt6769208',
#   'tt9253866',
#   'tt2395695',
#   'tt0081846',
#   'tt2861424',
#   'tt9566030',
#   'tt0141842',
#   'tt0417299',
#   'tt0071075',
#   'tt1533395',
#   'tt0111893',
#   'tt1475582',
#   'tt1877514',
#   'tt1355642',
#   'tt0052520',
#   'tt1806234',
#   'tt0092337',
#   'tt0303461',
#   'tt0098769',
#   'tt2356777',
#   'tt7137906',
#   'tt0103359',
#   'tt0296310',
#   'tt2802850',
#   'tt0877057',
#   'tt2092588',
#   'tt3530232',
#   'tt1190634',
#   'tt0213338',
#   'tt1508238',
#   'tt2571774',
#   'tt2085059',
#   'tt0081912',
#   'tt0063929',
#   'tt0081834',
#   'tt0108778',
#   'tt0112130',
#   'tt4508902',
#   'tt7920978',
#   'tt0098904',
#   'tt4742876',
#   'tt4574334',
#   'tt1865718',
#   'tt0098936',
#   'tt0386676',
#   'tt3718778',
#   'tt0367279',
#   'tt2707408',
#   'tt0193676',
#   'tt2442560',
# ...

# %%
response = requests.get("https://uflixit.p.rapidapi.com/tv-shows/popular",
  headers={
    "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
    "X-RapidAPI-Key": "****************************"   #uflixit api key
  }
)

# %%
response
# Out:
# <Response [404]>

# %%
response = requests.get("https://uflixit.p.rapidapi.com/movie/links/tt1234567?lang=en",
  headers={
    "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
    "X-RapidAPI-Key": "4ae47af3ccmsh91b5c261a9b9b26p1a9772jsne57decfbd06c"
  }
)

# %%
response
# Out:
# <Response [404]>

# %%
response = requests.get("https://uflixit.p.rapidapi.com/movie/details/tt1234567",
  headers={
    "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
    "X-RapidAPI-Key": "4ae47af3ccmsh91b5c261a9b9b26p1a9772jsne57decfbd06c"
  }
)

# %%
response
# Out:
# <Response [404]>

# %%
response = requests.get("https://uflixit.p.rapidapi.com/movie/links/tt01234567?lang=en",
  headers={
    "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
    "X-RapidAPI-Key": "7a19c1191dmsh541ae74fcd60759p1c1d68jsnfe0e28b393c8"
  }
)

# %%
response
# Out:
# <Response [404]>

# %%
x=['sparsh','jain','divya','jain']
for j in x:
    print(j)
# Out:
# sparsh
# jain
# divya
# jain

# %%
f=open("details.txt","r")
lod=json.load(f)
f.close()
lod
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-15-e5aaed47b212> in <module>
#       1 f=open("details.txt","r")
# ----> 2 lod=json.load(f)
#       3 f.close()
#       4 lod
#
# c:\users\sparsh jain\appdata\local\programs\python\python37-32\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# --> 296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     297
#     298
#
# c:\users\sparsh jain\appdata\local\programs\python\python37-32\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
# ...

# %%
l=[]
for x in lod:
    if x=="\n":
        continue
    else:
        l.append(x)
length=len(l)
for i in range(length):
    print(l[i]['title'])
# Out:
# Aladdin
# Godzilla: King of the Monsters
# Aladdin
# Avengers: Endgame
# Aladdin
# The Hustle
# Aladdin
# The Secret Life of Pets 2
# Aladdin
# Rocketman
# Aladdin
# Brightburn
# Aladdin
# Ma
# Aladdin
# John Wick: Chapter 3 – Parabellum
# Aladdin
# Shazam!
# Aladdin
# Aladdin
# Godzilla: King of the Monsters
# Godzilla: King of the Monsters
# Avengers: Endgame
# Godzilla: King of the Monsters

# %%
dictionary=dict()
f=open("Buster.txt","r")
ser=json.load(f)
f.close()
for x in response['result']:
    for i in range(len(ser)):
        if ser[i]['imdb_id']==x:
          dictionary[x]=ser[i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ab99cf7fe51a> in <module>
#       1 dictionary=dict()
#       2 f=open("Buster.txt","r")
# ----> 3 ser=json.load(f)
#       4 f.close()
#       5 for x in response['result']:
#
# NameError: name 'json' is not defined

# %%
import requests
import json
if __name__=="__main__":    
    l=[]
    response = requests.get("https://uflixit.p.rapidapi.com/movies/wanted",
    headers={
    "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
    "X-RapidAPI-Key": "************************************888"
  }).json()
    f=open("Buster.txt","r")
    da=json.load(f)
    f.close()
    for x in response['result']:
      for j in da:
        if j=="\n":
          continue
        else:        
          l.append(j)
          
          if j['imdb_id']==x:
            continue
          else:
            response1 = requests.get(f"https://uflixit.p.rapidapi.com/movie/details/{x}",
        headers={
          "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
          "X-RapidAPI-Key": "**************************************************88888"
            }).json()
            l.append(response1['result'])
    try:
            f=open("Buster.txt","w")
            json.dump(l,f)
            f.close()
    except Exception as exp:
            f=open("Exception.txt","a")
            json.dump(exp,f)
            f.close()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-4-707fb4b15b82> in <module>
#      24         headers={
#      25           "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
# ---> 26           "X-RapidAPI-Key": "7a19c1191dmsh541ae74fcd60759p1c1d68jsnfe0e28b393c8"
#      27             }).json()
#      28             l.append(response1['result'])
#
# c:\users\sparsh jain\appdata\local\programs\python\python37-32\lib\site-packages\requests\models.py in json(self, **kwargs)
#     894                     # used.
#     895                     pass
# --> 896         return complexjson.loads(self.text, **kwargs)
#     897
#     898     @property
#
# c:\users\sparsh jain\appdata\local\programs\python\python37-32\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
f=open("details.txt","r")
sd=json.load(f)
f.close()
sd
# Out:
# [{'error': False,
#   'result': {'title': 'The Jungle Book',
#    'rating': '7.4',
#    'duration': 106,
#    'content': 'PG',
#    'published': '2016-04-07',
#    'image': 'https://m.media-amazon.com/images/M/MV5BMTc3NTUzNTI4MV5BMl5BanBnXkFtZTgwNjU0NjU5NzE@._V1_.jpg',
#    'fanart': 'http://image.tmdb.org/t/p/original/eIOTsGg9FCVrBc4r2nXaV61JF4F.jpg',
#    'stars': ['Neel Sethi',
#     'Bill Murray',
#     'Ben Kingsley',
#     'Idris Elba',
#     "Lupita Nyong'o",
#     'Scarlett Johansson',
#     'Giancarlo Esposito',
#     'Christopher Walken',
#     'Garry Shandling',
#     'Brighton Rose',
#     'Emjay Anthony',
#     'Max Favreau',
#     'Chloe Hechter',
#     'Asher Blinkoff',
#     'Knox Gagnon',
#     'Sasha Schreiber',
#     'Kai Schreiber',
#     'Jon Favreau',
#     'Sam Raimi',
#     'Russell Peters',
#     'Madeleine Favreau',
#     'Ritesh Rajan',
#     'Kendrick Reyes',
#     'Sara Arrington',
#     'Sean W. Johnson',
#     'Artie Esposito',
#     'Allan Trautman',
# ...

# %%
print(sd)
# Out:
# [{'error': False, 'result': {'title': 'The Jungle Book', 'rating': '7.4', 'duration': 106, 'content': 'PG', 'published': '2016-04-07', 'image': 'https://m.media-amazon.com/images/M/MV5BMTc3NTUzNTI4MV5BMl5BanBnXkFtZTgwNjU0NjU5NzE@._V1_.jpg', 'fanart': 'http://image.tmdb.org/t/p/original/eIOTsGg9FCVrBc4r2nXaV61JF4F.jpg', 'stars': ['Neel Sethi', 'Bill Murray', 'Ben Kingsley', 'Idris Elba', "Lupita Nyong'o", 'Scarlett Johansson', 'Giancarlo Esposito', 'Christopher Walken', 'Garry Shandling', 'Brighton Rose', 'Emjay Anthony', 'Max Favreau', 'Chloe Hechter', 'Asher Blinkoff', 'Knox Gagnon', 'Sasha Schreiber', 'Kai Schreiber', 'Jon Favreau', 'Sam Raimi', 'Russell Peters', 'Madeleine Favreau', 'Ritesh Rajan', 'Kendrick Reyes', 'Sara Arrington', 'Sean W. Johnson', 'Artie Esposito', 'Allan Trautman', 'Dee Bradley Baker'], 'countries': ['UK', 'USA'], 'keywords': [], 'genres': ['Adventure', 'Drama', 'Family', 'Fantasy'], 'akas': [], 'trailer': '', 'director': 'Jon Favreau', 'summary': 'A man-cub
# ...

# %%
x=['Inception','Intersteller','Lords of Ring','Star wars','avatar','the hercules','Prisoners','Harry poter','jurrasic park']
l=[]
for j in x:
        data = requests.get(f"https://uflixit.p.rapidapi.com/movies/search?query={j}",headers={
    "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
    "X-RapidAPI-Key": "************************************"
        })
        data=data.json()
        response = requests.get(f"https://uflixit.p.rapidapi.com/movie/details/{data['result']['imdb_id']}",
        headers={
          "X-RapidAPI-Host": "uflixit.p.rapidapi.com",
          "X-RapidAPI-Key": "************************************************"
        })
        
        data1=response.json()
        l.append(data1)
f=open("top.txt","a")
json.dump(l,f)
f.close()

# %%
f=open("top.txt","r")
sds=json.load(f)
f.close()

# %%
# Out:
# [{'error': False,
#   'result': {'title': 'Inception',
#    'rating': '8.8',
#    'duration': 148,
#    'content': 'PG-13',
#    'published': '2010-07-15',
#    'image': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_.jpg',
#    'fanart': 'http://image.tmdb.org/t/p/original/s2bT29y0ngXxxu2IA8AOzzXTRhd.jpg',
#    'stars': ['Leonardo DiCaprio',
#     'Joseph Gordon-Levitt',
#     'Ellen Page',
#     'Tom Hardy',
#     'Ken Watanabe',
#     'Dileep Rao',
#     'Cillian Murphy',
#     'Tom Berenger',
#     'Marion Cotillard',
#     'Pete Postlethwaite',
#     'Michael Caine',
#     'Lukas Haas',
#     'Tai-Li Lee',
#     'Claire Geare',
#     'Magnus Nolan',
#     'Taylor Geare',
#     'Johnathan Geare',
#     'Tohoru Masamune',
#     'Yuji Okumoto',
#     'Earl Cameron',
#     'Ryan Hayward',
#     'Miranda Nolan',
#     'Russ Fega',
#     'Tim Kelleher',
#     'Talulah Riley',
#     'Nicolas Clerc',
#     'Coralie Dedykere',
# ...
